# %% [markdown]
# # The Purpose of this Jupyter Notebook is to demonstrate how the log data will be cleaned

# %%
import os
import pandas as pd
import re

# %%
def find_file(filename, data_directory):
    for root, _, files in os.walk(data_directory):
        if filename in files:
           
            return os.path.join(root, filename)
    return None

def find_parquet_file(filename, data_directory):
    """
    Searches for a Parquet "file" (directory or file) in a given directory.

    Args:
        filename (str): The name of the Parquet "file" (directory).
        data_directory (str): The root directory to search in.

    Returns:
        str: The full path to the Parquet directory or None if not found.
    """
    filename = filename.lower().strip()  # Normalize the filename
    for root, dirs, files in os.walk(data_directory):  # Include directories
        # Check if any directory matches the filename
        for dir_name in dirs:
            if dir_name.lower() == filename:
                print(f"Found Parquet directory: {dir_name}")
                return os.path.join(root, dir_name)

        # Additionally, check if there are .parquet files (optional)
        for file_name in files:
            if file_name.lower() == filename:
                print(f"Found Parquet file: {file_name}")
                return os.path.join(root, file_name)

    # No match found
    return None

data_dir = "./data"
file_name = "user_behavior_dataset.csv"
# Out:
# Found Parquet directory: log_devices_fplay.parquet
# ./data/intern/sample/log_devices_fplay.parquet

# %%
df_telecom = pd.read_csv(find_file("Log Device sample - FPT Telecom.csv", data_dir))
df_online_app = pd.read_csv(find_file("Log Device sample - FPT Online App.csv", data_dir))
df_hifpt = pd.read_csv(find_file("Log Device sample - FPT HiFPT.csv", data_dir))
df_play = pd.read_csv(find_file("Log Device sample - FPT Play.csv", data_dir))
df_online_web = pd.read_csv(find_file('Log Device sample - FPT Online Web.csv', data_dir))
df_log_sample = pd.read_csv(find_file("sample_data.csv", data_dir))

# %%
log_devices_dict = pd.read_parquet(find_file("log_devices_internet.parquet",data_dir))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 log_devices_dict = pd.read_parquet(find_file("log_devices_internet.parquet",data_dir))
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parquet.py:509, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     506     use_nullable_dtypes = False
#     507 check_dtype_backend(dtype_backend)
# --> 509 return impl.read(
#     510     path,
#     511     columns=columns,
#     512     storage_options=storage_options,
#     513     use_nullable_dtypes=use_nullable_dtypes,
#     514     dtype_backend=dtype_backend,
#     515     **kwargs,
#     516 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/parquet.py:227, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     220 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     221     path,
#     222     kwargs.pop("filesystem", None),
#     223     storage_options=storage_options,
#     224     mode="rb",
#     225 )
#     226 try:
# --> 227     pa_table = self.api.parquet.read_table(
#     228         path_or_handle, columns=columns, **kwargs
#     229     )
#     230     result = pa_table.to_pandas(**to_pandas_kwargs)
#     232     if manager == "array":
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/parquet/core.py:1793, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification)
#    1787     warnings.warn(
#    1788         "Passing 'use_legacy_dataset' is deprecated as of pyarrow 15.0.0 "
#    1789         "and will be removed in a future version.",
#    1790         FutureWarning, stacklevel=2)
#    1792 try:
# -> 1793     dataset = ParquetDataset(
#    1794         source,
#    1795         schema=schema,
#    1796         filesystem=filesystem,
#    1797         partitioning=partitioning,
#    1798         memory_map=memory_map,
#    1799         read_dictionary=read_dictionary,
#    1800         buffer_size=buffer_size,
#    1801         filters=filters,
#    1802         ignore_prefixes=ignore_prefixes,
#    1803         pre_buffer=pre_buffer,
#    1804         coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1805         decryption_properties=decryption_properties,
#    1806         thrift_string_size_limit=thrift_string_size_limit,
#    1807         thrift_container_size_limit=thrift_container_size_limit,
#    1808         page_checksum_verification=page_checksum_verification,
#    1809     )
#    1810 except ImportError:
#    1811     # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1812     # module is not available
#    1813     if filters is not None:
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/parquet/core.py:1371, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, use_legacy_dataset)
#    1367 if partitioning == "hive":
#    1368     partitioning = ds.HivePartitioning.discover(
#    1369         infer_dictionary=True)
# -> 1371 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1372                            schema=schema, format=parquet_format,
#    1373                            partitioning=partitioning,
#    1374                            ignore_prefixes=ignore_prefixes)
#
# File ~/.local/lib/python3.8/site-packages/pyarrow/dataset.py:814, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     812     return _in_memory_dataset(source, **kwargs)
#     813 else:
# --> 814     raise TypeError(
#     815         'Expected a path-like, list of path-likes or a list of Datasets '
#     816         'instead of the given type: {}'.format(type(source).__name__)
#     817     )
#
# TypeError: Expected a path-like, list of path-likes or a list of Datasets instead of the given type: NoneType

# %% [markdown]
# # PROCCESSING ONLINE WEB DATA

# %%
def proccess_online_web(df):
  '''
  Proccessing online web
  Should take uncleaned online web data
  Returns clean dataset to use.
  '''
  important_columns = [ #Take the important colums
        "cdp_id",
        "user_id",
        "device_brand",
        "device_model",
        "device_type",
        "os",
        "os_version",
        "user_agent",
        "context_device_model",
        "marketing_name"
    ]
  df_filtered = df[important_columns].copy()

  #Standarize text columns
  for col in ["device_brand", "device_model", "device_type", "os",
              "context_device_model", "marketing_name"]:
      if col in df_filtered.columns:
          df_filtered[col] = df_filtered[col].fillna("unknown").str.lower().str.strip().copy()

  #Fill missing user_agent and user_id
  df_filtered["user_agent"] = df_filtered["user_agent"].fillna("unknown")
  df_filtered["user_id"] = df_filtered["user_id"].fillna(-1).astype(int).astype(str)

  return df_filtered

#Processing Information
df_online_web_processed = proccess_online_web(df_online_web)
display(df_online_web_processed.sample(50))
# Out:
#                                    cdp_id     user_id     device_brand  \
# 985  884d11cc-27de-4c7e-8e62-96a87af30d47          -1            apple
# 309  b3af81ad-4b07-4f76-bdb5-70decb6343bd          -1  generic_android
# 473  80379e50-c72c-44cc-b15c-66199ef278e8          -1  generic_android
# 465  da8d3a1e-1977-499e-b8b5-9038650afe75          -1            apple
# 776  ae02ac3c-9ae3-4c40-8d45-40c8458e7ac9          -1            apple
# 675  b964b7d0-83f8-43ff-a63e-7358ec1e83e4          -1          unknown
# 283  888cfc20-3905-4834-b42d-71b2fbe8e834          -1          unknown
# 501  d780248c-6204-4551-8885-0811b433a610          -1            apple
# 152  64c23ac4-e42a-49b5-acfb-bddaba7dac6b          -1          unknown
# 466  77f7aba2-5fd2-48ec-bc2c-4563e3013688  1059938958  generic_android
# 812  f7802b90-cb68-42cc-9563-5aa9c4d3f09c          -1            apple
# 37   6acbb1e4-49fa-499d-8e6c-814381191179          -1          unknown
# 919  c1b6df5f-a6c8-4a81-9a89-beffe07192b8          -1           spider
# 11   b37aec40-42bf-4684-8444-11c3eb02f456          -1            apple
# 232  97ed9807-3cb6-4125-8185-aaeb0c4f9e68          -1  generic_android
# 771  2cfc8ec8-8e59-4178-be42-c0b4b6705d65          -1            apple
# 264  05182480-0659-47cc-b8fa-dce85a364b3a          -1          unknown
# 216  15284f2f-3558-4cbb-8e87-bdb8c831b654          -1             oppo
# 594  4cb7fe6d-0a6b-4998-9143-72e8e5ee673f          -1  generic_android
# 106  d74875ce-152e-4a52-a2fe-d7f1af22c15b          -1          unknown
# 194  b36e1389-9eec-467a-863c-e7ac4d5cdb15          -1          unknown
# 792  ef31b553-45c4-4400-ab47-42b523e45df5          -1            apple
# 409  a178609d-25bb-4746-ac7a-0901126b2d55          -1          unknown
# 755  532ec307-da71-47c2-b176-0bb9cc8878be          -1          unknown
# 899  4724921f-0c5b-41e0-8014-ff2fb25e8de7          -1            apple
# 859  2d52154a-61ba-43f2-b3e3-07f2e1e0dba3          -1            apple
# 99   02631601-a3e1-4d57-8ab2-00027973a764          -1          unknown
# 816  47584f96-9348-4d87-ae11-7014042c734f          -1            apple
# 392  d0af7035-f116-44d3-bb76-a28b06777081          -1  generic_android
# 310  6abca9c2-b793-4e31-89b3-f8394d92c1e7          -1            apple
# 561  6827325b-adb5-4f0a-8752-5ff60e435144          -1            apple
# 32   e3f1d8be-cad3-4313-9469-e63a5e0a9e17          -1            apple
# 925  1bf306fa-7359-4c39-ab06-1316d9cd4265          -1  generic_android
# 884  29349f17-bf36-47e9-ab36-8978bc41c112          -1            apple
# 713  92866cde-6fa7-4be0-8f0f-3b6ee03d6363          -1  generic_android
# 187  1f785d7e-c55f-497c-8cbe-7cfaca1019ff          -1            apple
# 544  8e874386-0b58-498c-95d0-b487ba286946          -1  generic_android
# 572  248a2c7d-45f1-4596-a3bc-4c2804360323          -1          unknown
# 967  22eff127-8a34-4c6f-b21b-2a0a2c5a6fb5          -1          unknown
# 422  619d2057-dc79-4393-8a75-7ba8daad186a          -1            apple
# 124  2500f784-42d2-453e-8643-1400ee23321c          -1            apple
# 476  f81b6f03-1dca-4c08-a99f-75b32812dc82          -1            apple
# 345  02f5531d-f035-4ad6-b5a6-de565733e8de          -1  generic_android
# 245  55897d1a-bd13-4211-a22a-35baecf3a23c     4168958          unknown
# 426  e36c06cf-4935-453f-941b-0a670b9bb801  1105072885  generic_android
# 75   dbc6cb75-da29-489e-a7a8-b8a72e22f71c          -1          unknown
# 686  d982c619-442d-40c1-ab61-16744c02deb5          -1  generic_android
# 371  c0b7540a-0e02-43d9-b52a-19f9457fbf2c          -1  generic_android
# 95   a2ec0a87-0ca0-47bc-9fff-9bd633322e6e          -1  generic_android
# 730  b9551bb0-9d5f-4dfc-8ab4-752b35dbf360          -1  generic_android
#
#                                           device_model device_type        os  \
# 985        iphone12,5/iphone11,4/iphone12,1/iphone11,8       phone       ios
# 309                                                  k     unknown   android
# 473                                                  k     unknown   android
# 465                                             iphone       phone       ios
# 776                                             iphone       phone       ios
# 675                                            unknown  pc/desktop   windows
# 283                                            unknown  pc/desktop   windows
# 501                                             iphone       phone       ios
# 152                                            unknown  pc/desktop   windows
# 466                                                  k     unknown   android
# 812                                             iphone       phone       ios
# 37                                             unknown  pc/desktop   windows
# 919                                            desktop      others   windows
# 11                                          iphone13,4       phone       ios
# 232                                                  k     unknown   android
# 771                                             iphone       phone       ios
# 264                                            unknown  pc/desktop   windows
# 216                                            cph2457       phone   android
# 594                                                  k     unknown   android
# 106                                            unknown  pc/desktop   windows
# 194                                            unknown  pc/desktop   windows
# 792                              iphone13,3/iphone13,2       phone       ios
# 409                                            unknown  pc/desktop   windows
# 755                                            unknown  pc/desktop   windows
# 899                                                mac  pc/desktop  mac os x
# 859                                             iphone       phone       ios
# 99                                             unknown  pc/desktop   windows
# 816                                             iphone       phone       ios
# 392                                                  k     unknown   android
# 310  ipad6,3/ipad6,4/ipad11,1/ipad11,2/ipad4,1/ipad...      tablet       ios
# 561        iphone12,5/iphone11,4/iphone12,1/iphone11,8       phone       ios
# 32                                                 mac  pc/desktop  mac os x
# 925                                                  k     unknown   android
# 884                                             iphone       phone       ios
# 713                                                  k     unknown   android
# 187                                             iphone       phone       ios
# 544                                                  k     unknown   android
# 572                                            unknown  pc/desktop     linux
# 967                                            unknown  pc/desktop   windows
# 422                                         iphone12,3       phone       ios
# 124                                         iphone10,1       phone       ios
# 476                                             iphone       phone       ios
# 345                                                  k     unknown   android
# 245                                            unknown  pc/desktop   windows
# 426                                                  k     unknown   android
# 75                                             unknown  pc/desktop   windows
# 686                                                  k     unknown   android
# 371                                                  k     unknown   android
# 95                                                   k     unknown   android
# 730                                                  k     unknown   android
#
#     os_version                                         user_agent  \
# 985       18.1  Mozilla/5.0 (iPhone; CPU iPhone OS 18_1 like M...
# 309         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 473         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 465       15.6  Mozilla/5.0 (iPhone; CPU iPhone OS 15_6 like M...
# 776     18.1.1  Mozilla/5.0 (iPhone; CPU iPhone OS 18_1_1 like...
# 675         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 283         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 501    16.7.10  Mozilla/5.0 (iPhone; CPU iPhone OS 16_7_10 lik...
# 152         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 466         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 812       18.2  Mozilla/5.0 (iPhone; CPU iPhone OS 18_2 like M...
# 37          10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 919         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 11        17.7  Mozilla/5.0 (iPhone; CPU iPhone OS 17_7 like M...
# 232         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 771     17.6.1  Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like...
# 264         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 216         14  Mozilla/5.0 (Linux; Android 14; CPH2457 Build/...
# 594         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 106         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 194         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 792         17  Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like M...
# 409         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 755         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 899    10.15.7  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 859       17.7  Mozilla/5.0 (iPhone; CPU iPhone OS 17_7 like M...
# 99          10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 816     18.2.0  Mozilla/5.0 (iPhone; CPU iPhone OS 18_2_0 like...
# 392         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 310     12.4.1  Mozilla/5.0 (iPad; CPU OS 12_4_1 like Mac OS X...
# 561     17.5.1  Mozilla/5.0 (iPhone; CPU iPhone OS 17_5_1 like...
# 32     10.15.7  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 925         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 884       18.1  Mozilla/5.0 (iPhone; CPU iPhone OS 18_1 like M...
# 713         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 187     18.1.1  Mozilla/5.0 (iPhone; CPU iPhone OS 18_1_1 like...
# 544         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 572        NaN  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 967         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 422     16.3.1  Mozilla/5.0 (iPhone; CPU iPhone OS 16_3_1 like...
# 124     15.8.3  Mozilla/5.0 (iPhone; CPU iPhone OS 15_8_3 like...
# 476       16.2  Mozilla/5.0 (iPhone; CPU iPhone OS 16_2 like M...
# 345         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 245         10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 426         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 75          10  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 686         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 371         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 95          10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
# 730         10  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...
#
#                                   context_device_model     marketing_name
# 985        iphone12,5/iphone11,4/iphone12,1/iphone11,8            unknown
# 309                                           sm-g780g            unknown
# 473                                           sm-j810y            unknown
# 465                                            unknown            unknown
# 776                                            unknown            unknown
# 675                                            unknown            unknown
# 283                                            unknown            unknown
# 501                                            unknown            unknown
# 152                                            unknown            unknown
# 466                                                  k            unknown
# 812                                            unknown            unknown
# 37                                             unknown            unknown
# 919                                            unknown            unknown
# 11                                          iphone13,4  iphone 12 pro max
# 232                                                  k            unknown
# 771                                            unknown            unknown
# 264                                            unknown            unknown
# 216                                            unknown            cph2457
# 594                                            unknown            unknown
# 106                                            unknown            unknown
# 194                                            unknown            unknown
# 792                              iphone13,3/iphone13,2            unknown
# 409                                            unknown            unknown
# 755                                            unknown            unknown
# 899                                            unknown            unknown
# 859                                            unknown            unknown
# 99                                             unknown            unknown
# 816                                            unknown            unknown
# 392                                                  k            unknown
# 310  ipad6,3/ipad6,4/ipad11,1/ipad11,2/ipad4,1/ipad...            unknown
# 561        iphone12,5/iphone11,4/iphone12,1/iphone11,8            unknown
# 32                                             unknown            unknown
# 925                                                  k            unknown
# 884                                            unknown            unknown
# 713                                                  k            unknown
# 187                                            unknown            unknown
# 544                                            unknown            unknown
# 572                                            unknown            unknown
# 967                                            unknown            unknown
# 422        iphone10,2/iphone12,3/iphone11,2/iphone10,3      iphone 11 pro
# 124                                         iphone10,1           iphone 8
# 476                                            unknown            unknown
# 345                                                  k            unknown
# 245                                            unknown            unknown
# 426                                                  k            unknown
# 75                                             unknown            unknown
# 686                                            unknown            unknown
# 371                                            unknown            unknown
# 95                                            sm-a035f            unknown
# 730                                           sm-s918b            unknown

# %% [markdown]
# # Processing_online_app

# %%
def procces_online_app(df):
    important_columns = [
      "user_agent",
      "brand",
      "model",
      "marketing_name",
      "os",
      "device_type",
      "is_mobile",
      "device_id"
    ]

    df_filtered = df[important_columns].copy()

    for col in ["brand", "model", "marketing_name", "os", "device_type", "device_id"]:
        if col in df_filtered.columns:
            df_filtered[col] = df_filtered[col].fillna("unknown").str.lower().str.strip()

    df_filtered["user_agent"] = df_filtered["user_agent"].fillna("unknown")
    
    return df_filtered

df_online_app_processed = procces_online_app(df_online_app)
df_online_app_processed.head(40)
# Out:
#                                            user_agent    brand  \
# 0                                             unknown  samsung
# 1                                             unknown  unknown
# 2                                             unknown     oppo
# 3    VnExpress/9.0.8 (iPhone; iOS 18.0.1; Scale/3.00)    apple
# 4                                             unknown    apple
# 5                                             unknown  samsung
# 6   Dalvik/2.1.0 (Linux; U; Android 12; SM-M536B B...  samsung
# 7                                             unknown    apple
# 8      VnExpress/9.0.8 (iPhone; iOS 18.0; Scale/3.00)    apple
# 9                                             unknown  unknown
# 10     VnExpress/8.7.0 (iPhone; iOS 18.2; Scale/3.00)    apple
# 11                                            unknown    apple
# 12       vRace/2.7.9 (iPhone; iOS 17.6.1; Scale/2.00)    apple
# 13   VnExpress/9.0.9 (iPhone; iOS 18.1.1; Scale/3.00)    apple
# 14                                            unknown  unknown
# 15                                            unknown  unknown
# 16   VnExpress/9.0.5 (iPhone; iOS 18.1.1; Scale/3.00)    apple
# 17                                            unknown  unknown
# 18                                            unknown   realme
# 19                                            unknown  unknown
# 20  VnExpress/9.0.6 (iPhone; iOS 16.7.10; Scale/3.00)    apple
# 21     VnExpress/9.0.8 (iPad; iOS 18.1.1; Scale/2.00)    apple
# 22   VnExpress/9.0.5 (iPhone; iOS 15.3.1; Scale/2.00)    apple
# 23                                            unknown  unknown
# 24                                            unknown    apple
# 25  Dalvik/2.1.0 (Linux; U; Android 14; 22120RN86G...  unknown
# 26   VnExpress/9.0.8 (iPhone; iOS 15.8.2; Scale/2.00)    apple
# 27                                            unknown  unknown
# 28  VnExpress/9.0.9 (iPhone; iOS 16.7.10; Scale/3.00)    apple
# 29                                            unknown  unknown
# 30  Dalvik/2.1.0 (Linux; U; Android 14; SM-A525F B...  samsung
# 31                                            unknown  samsung
# 32                                            unknown    apple
# 33   VnExpress/8.9.5 (iPhone; iOS 17.6.1; Scale/3.00)    apple
# 34                                            unknown  samsung
# 35     VnExpress/9.0.9 (iPhone; iOS 18.1; Scale/3.00)    apple
# 36                                            unknown    apple
# 37  Dalvik/2.1.0 (Linux; U; Android 14; 2406APNFAG...  unknown
# 38   VnExpress/9.0.9 (iPhone; iOS 18.1.1; Scale/3.00)    apple
# 39   VnExpress/9.0.8 (iPhone; iOS 18.1.1; Scale/3.00)    apple
#
#                                           model     marketing_name       os  \
# 0                                      sm-a225f         galaxy a22  android
# 1                                       unknown            unknown  windows
# 2                                       cph2461            unknown  android
# 3                                       unknown            unknown      ios
# 4                                       unknown            unknown      ios
# 5                                      sm-a505f         galaxy a50  android
# 6                                      sm-m536b            unknown  android
# 7                                       unknown            unknown      ios
# 8                                       unknown            unknown      ios
# 9                                       unknown            unknown  windows
# 10                                      unknown            unknown      ios
# 11                                   iphone13,4  iphone 12 pro max      ios
# 12                                      unknown            unknown      ios
# 13                                      unknown            unknown      ios
# 14                                      unknown            unknown  windows
# 15                                     sm-a528b            unknown  android
# 16                                      unknown            unknown      ios
# 17                                     sm-a127f            unknown  android
# 18                                      rmx3372            unknown  android
# 19                                            k            unknown  android
# 20                                      unknown            unknown      ios
# 21                                      unknown            unknown      ios
# 22                                      unknown            unknown      ios
# 23                                            k            unknown  android
# 24  iphone12,5/iphone11,4/iphone12,1/iphone11,8            unknown      ios
# 25                                   22120rn86g            unknown  android
# 26                                      unknown            unknown      ios
# 27                                            k            unknown  android
# 28                                      unknown            unknown      ios
# 29                                            k            unknown  android
# 30                                     sm-a525f         galaxy a52  android
# 31                                     sm-g361h  galaxy core prime  android
# 32  iphone12,5/iphone11,4/iphone12,1/iphone11,8            unknown      ios
# 33                                      unknown            unknown      ios
# 34                                     sm-j400f          galaxy j4  android
# 35                                      unknown            unknown      ios
# 36  iphone10,2/iphone12,3/iphone11,2/iphone10,3            unknown      ios
# 37                                   2406apnfag            unknown  android
# 38                                      unknown            unknown      ios
# 39                                      unknown            unknown      ios
#
#    device_type  is_mobile                             device_id
# 0       mobile       True                               unknown
# 1           pc      False                               unknown
# 2       mobile       True                               unknown
# 3       mobile       True  291d218e-4d1d-449f-bf9d-98fad20741e3
# 4       mobile       True                               unknown
# 5       mobile       True                               unknown
# 6       mobile       True      b8cefad0ee0014d65b2583078a66632a
# 7       mobile       True                               unknown
# 8       mobile       True  cb2e0e02-0e71-4eef-b07c-c2af13d7636f
# 9           pc      False                               unknown
# 10      mobile       True  b0b36f14-ce98-492b-bd01-5e47a6d26785
# 11      mobile       True                               unknown
# 12      mobile       True  d938404e-ddab-4994-85b8-e8212c5708bb
# 13      mobile       True  54b97978-e3a3-4472-acfc-c6ecf043f583
# 14          pc      False                               unknown
# 15      mobile       True                               unknown
# 16      mobile       True  d92f146f-bf41-477f-9396-def0cabbc580
# 17      mobile       True                               unknown
# 18      mobile       True                               unknown
# 19      mobile       True                               unknown
# 20      mobile       True  43260c25-c0c8-48eb-863d-9d586b3f261a
# 21      mobile       True  c5f72484-e82a-4bb7-90b9-9e07243cec82
# 22      mobile       True  82fec63f-deda-44d6-aacc-be859983e1f8
# 23      mobile       True                               unknown
# 24      mobile       True                               unknown
# 25      mobile       True      9c613312e4a2866b055ba110b0047f52
# 26      mobile       True  ad62682f-1040-4508-9fdf-3b7c3f494028
# 27      mobile       True                               unknown
# 28      mobile       True  1a6af5c7-5543-46d2-8d0f-75e22b7a2443
# 29      mobile       True                               unknown
# 30      mobile       True      dfec5f0825b2501e3e1f9a3e6e9f16db
# 31      mobile       True                               unknown
# 32      mobile       True                               unknown
# 33      mobile       True  507a833e-4e1a-49d6-a9e0-75583dd9a786
# 34      mobile       True                               unknown
# 35      mobile       True  b55d99bd-ceeb-47f5-80ae-d1be23791432
# 36      mobile       True                               unknown
# 37      mobile       True      2986b12540fca5bed28993bc02f0796c
# 38      mobile       True  6fd85af8-56f0-4915-944e-c937d19d2660
# 39      mobile       True  5d77d463-7856-4577-9ee3-fc86c5359aab

# %% [markdown]
# # Processing FPT hiFPT

# %%
def process_hifpt(df):
  '''
  Proccesing FPT HiFPT dataset
  '''
  important_columns = [
    "customer_id",
    "device_id",
    "device_name",
    "mac",
    "device_model",
    "brand",
    "marketing_name",
    "map_key"]

  df_filtered = df[important_columns].copy()

  for col in ["device_name", "device_model", "brand", "marketing_name", "mac", "map_key"]:
    if col in df_filtered.columns:
        df_filtered[col] = (
            df_filtered[col]
            .fillna("unknown")
            .astype(str)
            .str.lower()
            .str.strip())

  #Might have to change Nan values to unknown for string compatibility
  return df_filtered

df_hifpt_processed = process_hifpt(df_hifpt)
df_hifpt_processed.sample(50)
# Out:
#      customer_id                             device_id device_name      mac  \
# 76     8419436.0  3C54A2BB-591C-4FC2-95C7-D7DE85238AA3     unknown  unknown
# 61       76065.0                      a64a02bfa38ed9fa     unknown  unknown
# 309    3910020.0                      6a2a0377bd9be396     unknown  unknown
# 992          NaN                                   NaN     unknown  unknown
# 492    1666233.0                      b35b8bc5844aabde     unknown  unknown
# 432    6076233.0                      c10949bc243e83a4     unknown  unknown
# 216         -1.0                                   NaN     unknown  unknown
# 680    7418034.0                      fd7cf77bccd8b8ea     unknown  unknown
# 545    5314749.0                      11e5956afe39c015     unknown  unknown
# 86           NaN                      eecef2657ea7b38f     unknown  unknown
# 118    5552287.0  13C5D9D4-6B1D-4C8E-9C37-3AF2F7A75915     unknown  unknown
# 455    9672878.0                      1a9c6ac157eaf69f     unknown  unknown
# 805    9383285.0  EFCA3BBC-2F70-4EFE-803C-DC973F3940BE     unknown  unknown
# 323          NaN                                   NaN     unknown  unknown
# 454    3172737.0  3BFAF927-E25F-42DA-8EE6-6E7C55177194     unknown  unknown
# 241     124359.0  478DAE0A-76AA-4EF3-BA9A-CCDB843F1C70     unknown  unknown
# 211     646951.0                      f9bbd6d1874a3636     unknown  unknown
# 511    9931606.0  A50DB6AB-DF0E-4DF0-B3B6-5677C84611DD     unknown  unknown
# 997    8661690.0                      c40c954773e41652     unknown  unknown
# 727    6219388.0                      ecd27074792c5309     unknown  unknown
# 276    2987943.0  C682D8B8-725C-4F4F-9E36-F0BDE5AC066E     unknown  unknown
# 131    5490271.0                      816c1487f36fea74     unknown  unknown
# 210     239749.0  718BD441-92AC-421B-A43A-2A1239ACDCD7     unknown  unknown
# 538    8370235.0                      0727379968d7abeb     unknown  unknown
# 266    7736761.0                      6cc43e471226c371     unknown  unknown
# 871    7841650.0                      3eb3adb29c1c4c20     unknown  unknown
# 919          NaN                      8ab1f01cab9bc381     unknown  unknown
# 412      11897.0  C0A56B16-7DE7-47E2-98B8-074FE39C32FD     unknown  unknown
# 559    7751465.0  515F563A-AF3F-42D6-85F1-B1BC7A4395BE     unknown  unknown
# 667    4043162.0                      c4809de846e35419     unknown  unknown
# 63     8055257.0  37DEA00A-489F-4EB2-A067-0FC8B4B2FB84     unknown  unknown
# 391    2589098.0  AC596492-CF5F-494E-98E5-8D7F67EBD1BA     unknown  unknown
# 429    7849426.0  1585B870-0DAB-4435-9D3E-D47796EAF25E     unknown  unknown
# 599    9897617.0  76C78ABB-785B-4649-B679-83EED523182F     unknown  unknown
# 64     5279487.0                      59afcbff0cf2ffcb     unknown  unknown
# 92     8732897.0  A8AE8EB8-EABA-4DAE-9579-CBF9DD8E0BF9     unknown  unknown
# 126    1306657.0                      c28d04311544ce1c     unknown  unknown
# 168     852370.0  2B67204D-5A77-4107-AF1C-8FDF0998296C     unknown  unknown
# 339    2459601.0                      2bc79f1d3b25e87d     unknown  unknown
# 246          NaN  39C68FB7-6F85-4E1E-B809-AAFA98B5EEFA     unknown  unknown
# 505          NaN  C48CFD39-8CD3-4356-9698-BF082FB55078     unknown  unknown
# 303    9148506.0                      cd4a5995b664afbc     unknown  unknown
# 36     9436192.0                      955867d3e49c319b     unknown  unknown
# 938    4668760.0                      1603ecb64d996b3e     unknown  unknown
# 639         -1.0                                   NaN     unknown  unknown
# 734         -1.0                                   NaN     unknown  unknown
# 218     123551.0  5881F1A9-F228-4489-87AE-274D499A5A3F     unknown  unknown
# 159    8974163.0  2076D783-08F4-4FE7-9CC8-5E0EA08A1F2F     unknown  unknown
# 201          NaN  384BF709-E1CC-4BFF-887C-696A6547F312     unknown  unknown
# 353     477897.0                      ecdc869ebdbfff4d     unknown  unknown
#
#       device_model    brand     marketing_name  \
# 76      iphone15,4    apple          iphone 15
# 61         unknown  unknown            unknown
# 309        unknown  unknown            unknown
# 992        unknown  unknown            unknown
# 492        unknown  unknown            unknown
# 432        unknown  unknown            unknown
# 216        unknown  unknown            unknown
# 680     21081111rg   xiaomi                11t
# 545        unknown  unknown            unknown
# 86         unknown  unknown            unknown
# 118        unknown  unknown            unknown
# 455        unknown  unknown            unknown
# 805        unknown  unknown            unknown
# 323        unknown  unknown            unknown
# 454        unknown  unknown            unknown
# 241        unknown  unknown            unknown
# 211     24069ra21c   xiaomi      redmi turbo 3
# 511        unknown  unknown            unknown
# 997        unknown  unknown            unknown
# 727        unknown  unknown            unknown
# 276     iphone13,2    apple          iphone 12
# 131        unknown  unknown            unknown
# 210        unknown  unknown            unknown
# 538        unknown  unknown            unknown
# 266        unknown  unknown            unknown
# 871        rmx3710   realme            rmx3710
# 919        unknown  unknown            unknown
# 412        unknown  unknown            unknown
# 559  iphone 7 plus    apple      iphone 7 plus
# 667        unknown  unknown            unknown
# 63         unknown  unknown            unknown
# 391        unknown  unknown            unknown
# 429        unknown  unknown            unknown
# 599        unknown  unknown            unknown
# 64         unknown  unknown            unknown
# 92         unknown  unknown            unknown
# 126        unknown  unknown            unknown
# 168     iphone15,3    apple  iphone 14 pro max
# 339        unknown  unknown            unknown
# 246        unknown  unknown            unknown
# 505        unknown  unknown            unknown
# 303       sm-a505f  samsung         galaxy a50
# 36         unknown  unknown            unknown
# 938       sm-a336e  samsung      galaxy a33 5g
# 639        unknown  unknown            unknown
# 734        unknown  unknown            unknown
# 218        unknown  unknown            unknown
# 159        unknown  unknown            unknown
# 201        unknown  unknown            unknown
# 353        unknown  unknown            unknown
#
#                                                map_key
# 76   3c54a2bb-591c-4fc2-95c7-d7de85238aa3|none|none...
# 61   a64a02bfa38ed9fa|none|none|none|none|none|none...
# 309  6a2a0377bd9be396|none|none|none|none|none|none...
# 992              |none|none|none|none|none|none|others
# 492  b35b8bc5844aabde|none|none|none|none|none|none...
# 432  c10949bc243e83a4|none|none|none|none|none|none...
# 216              |none|none|none|none|none|none|others
# 680  fd7cf77bccd8b8ea|none|none|none|21081111rg|xia...
# 545  11e5956afe39c015|none|none|none|none|none|none...
# 86   eecef2657ea7b38f|none|none|none|none|none|none...
# 118  13c5d9d4-6b1d-4c8e-9c37-3af2f7a75915|none|none...
# 455  1a9c6ac157eaf69f|none|none|none|none|none|none...
# 805  efca3bbc-2f70-4efe-803c-dc973f3940be|none|none...
# 323              |none|none|none|none|none|none|others
# 454  3bfaf927-e25f-42da-8ee6-6e7c55177194|none|none...
# 241  478dae0a-76aa-4ef3-ba9a-ccdb843f1c70|none|none...
# 211  f9bbd6d1874a3636|none|none|none|24069ra21c|xia...
# 511  a50db6ab-df0e-4df0-b3b6-5677c84611dd|none|none...
# 997  c40c954773e41652|none|none|none|none|none|none...
# 727  ecd27074792c5309|none|none|none|none|none|none...
# 276  c682d8b8-725c-4f4f-9e36-f0bde5ac066e|none|none...
# 131  816c1487f36fea74|none|none|none|none|none|none...
# 210  718bd441-92ac-421b-a43a-2a1239acdcd7|none|none...
# 538  0727379968d7abeb|none|none|none|none|none|none...
# 266  6cc43e471226c371|none|none|none|none|none|none...
# 871  3eb3adb29c1c4c20|none|none|none|rmx3710|realme...
# 919  8ab1f01cab9bc381|none|none|none|none|none|none...
# 412  c0a56b16-7de7-47e2-98b8-074fe39c32fd|none|none...
# 559  515f563a-af3f-42d6-85f1-b1bc7a4395be|none|none...
# 667  c4809de846e35419|none|none|none|none|none|none...
# 63   37dea00a-489f-4eb2-a067-0fc8b4b2fb84|none|none...
# 391  ac596492-cf5f-494e-98e5-8d7f67ebd1ba|none|none...
# 429  1585b870-0dab-4435-9d3e-d47796eaf25e|none|none...
# 599  76c78abb-785b-4649-b679-83eed523182f|none|none...
# 64   59afcbff0cf2ffcb|none|none|none|none|none|none...
# 92   a8ae8eb8-eaba-4dae-9579-cbf9dd8e0bf9|none|none...
# 126  c28d04311544ce1c|none|none|none|none|none|none...
# 168  2b67204d-5a77-4107-af1c-8fdf0998296c|none|none...
# 339  2bc79f1d3b25e87d|none|none|none|none|none|none...
# 246  39c68fb7-6f85-4e1e-b809-aafa98b5eefa|none|none...
# 505  c48cfd39-8cd3-4356-9698-bf082fb55078|none|none...
# 303  cd4a5995b664afbc|none|none|none|sm-a505f|samsu...
# 36   955867d3e49c319b|none|none|none|none|none|none...
# 938  1603ecb64d996b3e|none|none|none|sm-a336e|samsu...
# 639              |none|none|none|none|none|none|others
# 734              |none|none|none|none|none|none|others
# 218  5881f1a9-f228-4489-87ae-274d499a5a3f|none|none...
# 159  2076d783-08f4-4fe7-9cc8-5e0ea08a1f2f|none|none...
# 201  384bf709-e1cc-4bff-887c-696a6547f312|none|none...
# 353  ecdc869ebdbfff4d|none|none|none|none|none|none...

# %% [markdown]
# # Process Telecom data

# %%
def proccess_telecom(df):
  '''
  Proccess the FPT telecom dataset.
  Takes the ubncleaned dataset as input and returns cleaned version
  '''
  important_columns = [
    "mac_device",
    "device_type",
    "device_name",
    "vendor_short",
    "vendor",
    "source"
  ]

  df_filtered = df[important_columns].copy()

  for col in ["device_name", "vendor_short", "vendor", "source"]:
    if col in df_filtered.columns:
        df_filtered[col] = (
            df_filtered[col]
            .fillna("unknown")
            .astype(str)
            .str.lower()
            .str.strip()
            )

  return df_filtered

df_telecom_processed = proccess_telecom(df_telecom)
df_telecom_processed.head(80)
# Out:
#            mac_device device_type          device_name vendor_short  \
# 0   A0:FF:0C:59:2E:C2     unknown              unknown      unknown
# 1   e6:4c:eb:88:6f:35       phone               iphone        apple
# 2   34:c6:dd:e2:db:ec       chaos  c6n_bd9618257_ezviz      unknown
# 3   32:73:12:7a:fd:d7       phone              unknown      unknown
# 4   d0:7f:a0:29:be:a1       phone    iphone-15-pro-max      samsung
# ..                ...         ...                  ...          ...
# 75  66:e9:10:bf:48:29     unknown              unknown      unknown
# 76  1e:1f:27:43:7b:39       chaos              unknown      unknown
# 77  3a:ce:25:ae:ff:84       phone           galaxy-a24      samsung
# 78  ce:38:be:75:cf:7d       phone      realme-c11-2021       realme
# 79  d6:5b:4e:35:50:00       chaos              unknown      unknown
#
#                          vendor source
# 0                       unknown  hwifi
# 1                       unknown  hwifi
# 2                       unknown  hwifi
# 3                       unknown    cpe
# 4   samsung electronics co, ltd  hwifi
# ..                          ...    ...
# 75                      unknown    cpe
# 76                      unknown  hwifi
# 77                      unknown    cpe
# 78                      unknown    cpe
# 79                      unknown  hwifi
#
# [80 rows x 6 columns]

# %% [markdown]
# # Process FPT Play

# %%
def process_fpt_play(df):
    '''
    Process the FPT Play dataset.
    Takes the uncleaned dataset as input and returns a cleaned version.
    '''
    important_columns = [
        "user_agent",
        "device_id",
        "model",
        "os",
        "os_version",
        "platform",
        "device_type",
        "mac"
    ]

    # Filter important columns
    df_filtered = df[important_columns].copy()

    # Standardize text columns
    for col in ["model", "os", "platform", "device_type"]:
        if col in df_filtered.columns:
            df_filtered[col] = (
                df_filtered[col]
                .fillna("unknown")
                .astype(str)
                .str.lower()
                .str.strip()
            )

    # Ensure device_id and mac are strings
    df_filtered["user_agent"] = df_filtered["user_agent"].fillna("unknown").astype(str)
    df_filtered["device_id"] = df_filtered["device_id"].fillna("unknown").astype(str)
    df_filtered["mac"] = df_filtered["mac"].fillna("unknown").astype(str)

    return df_filtered

# Apply the function to the FPT Play dataset
df_fpt_play_processed = process_fpt_play(df_play)

# Display the first few rows of the cleaned dataset
df_fpt_play_processed.sample(50)
# Out:
#                                             user_agent  \
# 253                                            unknown
# 151                                            unknown
# 66                                             unknown
# 252                                            unknown
# 199                                            unknown
# 988                                            unknown
# 28                                             unknown
# 991                                            unknown
# 180                                            unknown
# 350                                            unknown
# 960                                            unknown
# 341                                            unknown
# 446                                            unknown
# 990                                            unknown
# 274                                            unknown
# 306                                            unknown
# 530                                            unknown
# 633                                            unknown
# 271                                            unknown
# 963                                            unknown
# 380                                            unknown
# 441                                            unknown
# 932                                            unknown
# 596                                            unknown
# 646                                            unknown
# 716                                            unknown
# 49                                             unknown
# 55                                             unknown
# 795                                            unknown
# 967                                            unknown
# 228                                            unknown
# 922                                            unknown
# 412                                            unknown
# 17                                             unknown
# 628                                            unknown
# 845                                            unknown
# 825                                            unknown
# 374                                            unknown
# 870                                            unknown
# 647  Mozilla/5.0 (Web0S; Linux/SmartTV) AppleWebKit...
# 98                                             unknown
# 610                                            unknown
# 99                                             unknown
# 965                                            unknown
# 894                                            unknown
# 438                                            unknown
# 930                                            unknown
# 850                                            unknown
# 196                                            unknown
# 42                                             unknown
#
#                                 device_id              model            os  \
# 253                      80b6e0d26ac909b8   vnpt smartbox 2x       android
# 151  93870747-39fe-c758-6062-47fcf1ce9991        55up7550ptc          html
# 66                      FC:57:03:D9:4A:06       fpt play 650       android
# 252  1bd0dee9-bc31-be5c-7b92-ecc4adc4f53a        55nano76sqa          html
# 199                     D4:CF:F9:6F:A8:15     fpt play box s       android
# 988  f1e89aee-582d-cc5e-48fa-0a42f97f88e9        43uj632t-ta          html
# 28                      FC:57:03:07:07:C2       fpt play 650       android
# 991                     10:39:4E:8F:02:A4       fpt play 650       android
# 180                     10:39:4E:D9:0D:6F       fpt play 650       android
# 350                     00:09:74:82:67:03       fpt play 650       android
# 960  C14E2146-BBD1-466B-BA3F-6E194322F943      iphone 12 pro           ios
# 341  E1B08A12-4A1D-4018-8B1B-39D8A057832F          iphone 12           ios
# 446  0B4FCED0-86B0-47D2-B42E-FE6C2C954F8F      iphone xs max           ios
# 990  BF4D5353-5D10-4A8C-930E-A2DB4B9F83FD     iphone 15 plus           ios
# 274                      c834d42980570ecc         bravia vu1       android
# 306  56859A94-8240-421E-939A-10E986513ED4      iphone 8 plus           ios
# 530                     FC:57:03:07:59:AD       fpt play 650       android
# 633  7AAB18A6-FC02-4F4F-BEEF-D7D5CA09392E          iphone 11           ios
# 271                     FC:57:03:14:2D:37       fpt play 650       android
# 963                     FC:57:03:93:5E:0A       fpt play 650       android
# 380                     00:09:74:87:2E:22       fpt play 650       android
# 441                     00:09:74:81:F1:31       fpt play 650       android
# 932                     10:39:4E:8A:64:93       fpt play 650       android
# 596  7be08df5-8592-0858-5856-801e6f76fd60        65uq8000psc          html
# 646                     10:39:4E:D8:57:CD       fpt play 650       android
# 716                      156fd162c8ba9c7e           smart tv       android
# 49                       0b1ecd41c19fbb93           smart tv       android
# 55                      10:39:4E:8F:94:B9       fpt play 650       android
# 795                     10:39:4E:D9:68:89       fpt play 650       android
# 967                     FC:D5:D9:77:E1:5E   fpt atv play box       android
# 228  BEF852DC-4E2E-466B-ADCC-8609CCD753D4     iphone 15 plus           ios
# 922                     10:39:4E:8F:B8:63       fpt play 650       android
# 412                     D4:CF:F9:63:33:91     fpt play box +       android
# 17                       34c554dcef9d6cfd           sm-g935l       android
# 628                     FC:57:03:13:C1:B4       fpt play 650       android
# 845  CF29883F-6419-4BDB-9E32-B4A4EAD5C195  iphone 15 pro max           ios
# 825                     00:09:74:88:5C:69       fpt play 650       android
# 374                     FC:57:03:15:8D:57       fpt play 650       android
# 870  BAD06CFB-0CCD-4DEC-9C67-F8128C931F4F          iphone 13           ios
# 647  6c5cfd8c-75c7-4c52-48cb-e317d1006f84        43uh617t-tb  other mobile
# 98                      FC:57:03:D9:1A:BD       fpt play 650       android
# 610                     FC:D5:D9:25:E7:BC   fpt atv play box       android
# 99   30729488-D830-4F87-996D-3AC0D3981760          iphone xr           ios
# 965                     FC:D5:D9:41:C7:BA   fpt atv play box       android
# 894                      eada46d2750bb9b3           smart tv       android
# 438                     FC:57:03:14:02:5A       fpt play 650       android
# 930                     10:39:4E:8F:5A:08       fpt play 650       android
# 850                     FC:57:03:15:63:40       fpt play 650       android
# 196                     FC:57:03:74:2B:04       fpt play 650       android
# 42                       8dcd41727df9a626        bravia 2015       android
#
#     os_version            platform device_type                mac
# 253          9     smart-tv-normal     smarttv            unknown
# 151        NaN  smarttv-lg-nextgen     smarttv  74:E6:B8:4F:85:8E
# 66          11          boxhis2022         box            unknown
# 252        NaN  smarttv-lg-nextgen     smarttv  00:A1:59:78:FC:80
# 199         10          boxsei2021         box            unknown
# 988        NaN  smarttv-lg-nextgen     smarttv            unknown
# 28          11          boxhis2022         box            unknown
# 991         11          boxhis2022         box            unknown
# 180         11          boxhis2022         box            unknown
# 350         11         boxinno2022         box            unknown
# 960     16.6.1                 ios      mobile            unknown
# 341     17.6.1                 ios      mobile            unknown
# 446     18.1.1                 ios      mobile            unknown
# 990         18                 ios      mobile            unknown
# 274         11                sony     smarttv            unknown
# 306    16.7.10                 ios      mobile            unknown
# 530         11          boxhis2022         box            unknown
# 633     17.2.1                 ios      mobile            unknown
# 271         11          boxhis2022         box            unknown
# 963         11          boxhis2022         box            unknown
# 380         11         boxinno2022         box            unknown
# 441         11         boxinno2022         box            unknown
# 932         11          boxhis2022         box            unknown
# 596        NaN  smarttv-lg-nextgen     smarttv  7C:64:6C:7B:84:24
# 646         11          boxhis2022         box            unknown
# 716         11                 tcl     smarttv            unknown
# 49          11                 tcl     smarttv            unknown
# 55          11          boxhis2022         box            unknown
# 795         11          boxhis2022         box            unknown
# 967          9             box2019         box            unknown
# 228     17.0.2                 ios      mobile            unknown
# 922         11          boxhis2022         box            unknown
# 412         10          boxsei2020         box            unknown
# 17       8.0.0    android - normal      mobile            unknown
# 628         11          boxhis2022         box            unknown
# 845       18.2                 ios      mobile            unknown
# 825         11         boxinno2022         box            unknown
# 374         11          boxhis2023         box            unknown
# 870       18.2                 ios      mobile            unknown
# 647      3.4.0  smarttv-lg-nextgen     smarttv            unknown
# 98          11          boxhis2022         box            unknown
# 610          9             box2019         box            unknown
# 99      18.1.1                 ios      mobile            unknown
# 965          9             box2019         box            unknown
# 894         11                 tcl     smarttv            unknown
# 438         11          boxhis2022         box            unknown
# 930         11          boxhis2022         box            unknown
# 850         11          boxhis2023         box            unknown
# 196         11          boxhis2022         box            unknown
# 42       8.0.0                sony     smarttv            unknown
